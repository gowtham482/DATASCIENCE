# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("admission_predict.csv")

# %%
df
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0             1        337          118                  4  4.5  4.5  9.65
# 1             2        324          107                  4  4.0  4.5  8.87
# 2             3        316          104                  3  3.0  3.5  8.00
# 3             4        322          110                  3  3.5  2.5  8.67
# 4             5        314          103                  2  2.0  3.0  8.21
# ..          ...        ...          ...                ...  ...  ...   ...
# 395         396        324          110                  3  3.5  3.5  9.04
# 396         397        325          107                  3  3.0  3.5  9.11
# 397         398        330          116                  4  5.0  4.5  9.45
# 398         399        312          103                  3  3.5  4.0  8.78
# 399         400        333          117                  4  5.0  4.0  9.66
#
#      Research  Chance of Admit
# 0           1             0.92
# ...

# %%
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0           1        337          118                  4  4.5  4.5  9.65
# 1           2        324          107                  4  4.0  4.5  8.87
# 2           3        316          104                  3  3.0  3.5  8.00
# 3           4        322          110                  3  3.5  2.5  8.67
# 4           5        314          103                  2  2.0  3.0  8.21
#
#    Research  Chance of Admit
# 0         1             0.92
# 1         1             0.76
# 2         1             0.72
# 3         1             0.80
# 4         0             0.65

# %%
df.tail()
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 395         396        324          110                  3  3.5  3.5  9.04
# 396         397        325          107                  3  3.0  3.5  9.11
# 397         398        330          116                  4  5.0  4.5  9.45
# 398         399        312          103                  3  3.5  4.0  8.78
# 399         400        333          117                  4  5.0  4.0  9.66
#
#      Research  Chance of Admit
# 395         1             0.82
# 396         1             0.84
# 397         1             0.91
# 398         0             0.67
# 399         1             0.95

# %%
df.columns
# Out:
# Index(['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP',
#        'LOR', 'CGPA', 'Research', 'Chance of Admit'],
#       dtype='object')

# %%
df.shape
# Out:
# (400, 9)

# %%
df.size
# Out:
# 3600

# %%
df.isnull().sum()
# Out:
# Serial No.           0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %%
df
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0             1        337          118                  4  4.5  4.5  9.65
# 1             2        324          107                  4  4.0  4.5  8.87
# 2             3        316          104                  3  3.0  3.5  8.00
# 3             4        322          110                  3  3.5  2.5  8.67
# 4             5        314          103                  2  2.0  3.0  8.21
# ..          ...        ...          ...                ...  ...  ...   ...
# 395         396        324          110                  3  3.5  3.5  9.04
# 396         397        325          107                  3  3.0  3.5  9.11
# 397         398        330          116                  4  5.0  4.5  9.45
# 398         399        312          103                  3  3.5  4.0  8.78
# 399         400        333          117                  4  5.0  4.0  9.66
#
#      Research  Chance of Admit
# 0           1             0.92
# ...

# %%
# Display all rows where GRE Score is greater than 320.
df[df["GRE Score"] > 320]
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0             1        337          118                  4  4.5  4.5  9.65
# 1             2        324          107                  4  4.0  4.5  8.87
# 3             4        322          110                  3  3.5  2.5  8.67
# 5             6        330          115                  5  4.5  3.0  9.34
# 6             7        321          109                  3  3.0  4.0  8.20
# ..          ...        ...          ...                ...  ...  ...   ...
# 394         395        329          111                  4  4.5  4.0  9.23
# 395         396        324          110                  3  3.5  3.5  9.04
# 396         397        325          107                  3  3.0  3.5  9.11
# 397         398        330          116                  4  5.0  4.5  9.45
# 399         400        333          117                  4  5.0  4.0  9.66
#
#      Research  Chance of Admit
# 0           1             0.92
# ...

# %%
#Show applicants whose TOEFL Score is less than 100.
df[df["TOEFL Score"]<100]
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 27           28        298           98                  2  1.5  2.5  7.50
# 28           29        295           93                  1  2.0  2.0  7.20
# 29           30        310           99                  2  1.5  2.0  7.30
# 30           31        300           97                  2  3.0  3.0  8.10
# 50           51        313           98                  3  2.5  4.5  8.30
# 57           58        298           99                  2  4.0  2.0  7.60
# 58           59        300           99                  1  3.0  2.0  6.80
# 77           78        301           99                  2  3.0  2.0  8.22
# 78           79        296           95                  2  3.0  2.0  7.54
# 79           80        294           93                  1  1.5  2.0  7.36
# 91           92        299           97                  3  5.0  3.5  7.66
# ...

# %%
# Get records where University Rating equals 5.
df[df["University Rating"]==5]
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 5             6        330          115                  5  4.5  3.0  9.34
# 22           23        328          116                  5  5.0  5.0  9.50
# 23           24        334          119                  5  5.0  4.5  9.70
# 24           25        336          119                  5  4.0  3.5  9.80
# 25           26        340          120                  5  4.5  4.5  9.60
# 26           27        322          109                  5  4.5  3.5  8.80
# 33           34        340          114                  5  4.0  4.0  9.60
# 34           35        331          112                  5  4.0  5.0  9.80
# 35           36        320          110                  5  5.0  5.0  9.20
# 44           45        326          113                  5  4.5  4.0  9.40
# 45           46        322          110                  5  5.0  4.0  9.10
# ...

# %%
#Select all students who have done Research (value 1).
df[df["Research"]==1]
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0             1        337          118                  4  4.5  4.5  9.65
# 1             2        324          107                  4  4.0  4.5  8.87
# 2             3        316          104                  3  3.0  3.5  8.00
# 3             4        322          110                  3  3.5  2.5  8.67
# 5             6        330          115                  5  4.5  3.0  9.34
# ..          ...        ...          ...                ...  ...  ...   ...
# 394         395        329          111                  4  4.5  4.0  9.23
# 395         396        324          110                  3  3.5  3.5  9.04
# 396         397        325          107                  3  3.0  3.5  9.11
# 397         398        330          116                  4  5.0  4.5  9.45
# 399         400        333          117                  4  5.0  4.0  9.66
#
#      Research  Chance of Admit
# 0           1             0.92
# ...

# %%
#Display students who have not done Research (value 0).
df[df["Research"]==0]
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 4             5        314          103                  2  2.0  3.0  8.21
# 7             8        308          101                  2  3.0  4.0  7.90
# 8             9        302          102                  1  2.0  1.5  8.00
# 9            10        323          108                  3  3.5  3.0  8.60
# 15           16        314          105                  3  3.5  2.5  8.30
# ..          ...        ...          ...                ...  ...  ...   ...
# 388         389        296           97                  2  1.5  2.0  7.80
# 390         391        314          102                  2  2.0  2.5  8.24
# 391         392        318          106                  3  2.0  3.0  8.65
# 393         394        317          104                  2  3.0  3.0  8.76
# 398         399        312          103                  3  3.5  4.0  8.78
#
#      Research  Chance of Admit
# 4           0             0.65
# ...

# %%
#Find applicants with CGPA greater than 9.0.
df[df["CGPA"]>9.0]
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0             1        337          118                  4  4.5  4.5  9.65
# 5             6        330          115                  5  4.5  3.0  9.34
# 12           13        328          112                  4  4.0  4.5  9.10
# 22           23        328          116                  5  5.0  5.0  9.50
# 23           24        334          119                  5  5.0  4.5  9.70
# ..          ...        ...          ...                ...  ...  ...   ...
# 394         395        329          111                  4  4.5  4.0  9.23
# 395         396        324          110                  3  3.5  3.5  9.04
# 396         397        325          107                  3  3.0  3.5  9.11
# 397         398        330          116                  4  5.0  4.5  9.45
# 399         400        333          117                  4  5.0  4.0  9.66
#
#      Research  Chance of Admit
# 0           1             0.92
# ...

# %%
df[(df["GRE Score"]>320) & (df['CGPA']>9.0)]
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0             1        337          118                  4  4.5  4.5  9.65
# 5             6        330          115                  5  4.5  3.0  9.34
# 12           13        328          112                  4  4.0  4.5  9.10
# 22           23        328          116                  5  5.0  5.0  9.50
# 23           24        334          119                  5  5.0  4.5  9.70
# ..          ...        ...          ...                ...  ...  ...   ...
# 394         395        329          111                  4  4.5  4.0  9.23
# 395         396        324          110                  3  3.5  3.5  9.04
# 396         397        325          107                  3  3.0  3.5  9.11
# 397         398        330          116                  4  5.0  4.5  9.45
# 399         400        333          117                  4  5.0  4.0  9.66
#
#      Research  Chance of Admit
# 0           1             0.92
# ...

# %%
(df['CGPA']>9.0)
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 395     True
# 396     True
# 397     True
# 398    False
# 399     True
# Name: CGPA, Length: 400, dtype: bool

# %%
#Display records where either SOP or LOR rating is 5.0
df[(df["SOP"]==5.0)|(df["LOR"]==5.0)]
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 22           23        328          116                  5  5.0  5.0  9.50
# 23           24        334          119                  5  5.0  4.5  9.70
# 34           35        331          112                  5  4.0  5.0  9.80
# 35           36        320          110                  5  5.0  5.0  9.20
# 45           46        322          110                  5  5.0  4.0  9.10
# 46           47        329          114                  5  4.0  5.0  9.30
# 48           49        321          110                  3  3.5  5.0  8.85
# 70           71        332          118                  5  5.0  5.0  9.64
# 71           72        336          112                  5  5.0  5.0  9.76
# 72           73        321          111                  5  5.0  5.0  9.45
# 74           75        314          106                  3  3.0  5.0  8.90
# ...

# %%
#Get rows where Chance of Admit is above 0.8 and University Rating ≥ 4.
(df["Chance of Admit"]>0.8) & (df["University Rating"]>=4)
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 395    False
# 396    False
# 397     True
# 398    False
# 399     True
# Length: 400, dtype: bool

# %%
df[(df["Chance of Admit"]>0.8) & (df['University Rating']>=4)]
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0             1        337          118                  4  4.5  4.5  9.65
# 5             6        330          115                  5  4.5  3.0  9.34
# 11           12        327          111                  4  4.0  4.5  9.00
# 22           23        328          116                  5  5.0  5.0  9.50
# 23           24        334          119                  5  5.0  4.5  9.70
# ..          ...        ...          ...                ...  ...  ...   ...
# 385         386        335          117                  5  5.0  5.0  9.82
# 392         393        326          112                  4  4.0  3.5  9.12
# 394         395        329          111                  4  4.5  4.0  9.23
# 397         398        330          116                  4  5.0  4.5  9.45
# 399         400        333          117                  4  5.0  4.0  9.66
#
#      Research  Chance of Admit
# 0           1             0.92
# ...

# %%
#Find all rows where TOEFL Score is between 100 and 110.
df[df["TOEFL Score"].between(100, 110)]
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 1             2        324          107                  4  4.0  4.5  8.87
# 2             3        316          104                  3  3.0  3.5  8.00
# 3             4        322          110                  3  3.5  2.5  8.67
# 4             5        314          103                  2  2.0  3.0  8.21
# 6             7        321          109                  3  3.0  4.0  8.20
# ..          ...        ...          ...                ...  ...  ...   ...
# 391         392        318          106                  3  2.0  3.0  8.65
# 393         394        317          104                  2  3.0  3.0  8.76
# 395         396        324          110                  3  3.5  3.5  9.04
# 396         397        325          107                  3  3.0  3.5  9.11
# 398         399        312          103                  3  3.5  4.0  8.78
#
#      Research  Chance of Admit
# 1           1             0.76
# ...

# %%
# Display data for students whose GRE Score is not equal to 300.
df[df["GRE Score"]!=300]
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0             1        337          118                  4  4.5  4.5  9.65
# 1             2        324          107                  4  4.0  4.5  8.87
# 2             3        316          104                  3  3.0  3.5  8.00
# 3             4        322          110                  3  3.5  2.5  8.67
# 4             5        314          103                  2  2.0  3.0  8.21
# ..          ...        ...          ...                ...  ...  ...   ...
# 395         396        324          110                  3  3.5  3.5  9.04
# 396         397        325          107                  3  3.0  3.5  9.11
# 397         398        330          116                  4  5.0  4.5  9.45
# 398         399        312          103                  3  3.5  4.0  8.78
# 399         400        333          117                  4  5.0  4.0  9.66
#
#      Research  Chance of Admit
# 0           1             0.92
# ...

# %%
#Show all students with CGPA less than 8 and Research = 1.
df[(df["CGPA"]<8) & (df["Research"]==1)]
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 20           21        312          107                  3  3.0  2.0  7.90
# 27           28        298           98                  2  1.5  2.5  7.50
# 51           52        312          100                  2  1.5  3.5  7.90
# 58           59        300           99                  1  3.0  2.0  6.80
# 78           79        296           95                  2  3.0  2.0  7.54
# 90           91        318          106                  2  4.0  4.0  7.92
# 93           94        301           97                  2  3.0  3.0  7.88
# 168         169        293           97                  2  2.0  4.0  7.80
# 357         358        301          104                  2  3.5  3.5  7.89
#
#      Research  Chance of Admit
# 20          1             0.64
# 27          1             0.44
# 51          1             0.56
# 58          1             0.36
# 78          1             0.44
# ...

# %%
#Retrieve rows where University Rating &lt; 3 and SOP &gt; 4.
df[(df["University Rating"]<3) & (df["SOP"]>4)]
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 103         104        317          104                  2  4.5  4.0  8.47
# 138         139        326          116                  2  4.5  3.0  9.08
# 141         142        332          118                  2  4.5  3.5  9.36
#
#      Research  Chance of Admit
# 103         0             0.57
# 138         1             0.80
# 141         1             0.90

# %%
#Get records of students having TOEFL Score &gt; 105 but GRE Score &lt; 310.
df[(df["TOEFL Score"]>105) & (df["GRE Score"]<310)]
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 13           14        307          109                  3  4.0  3.0  8.00
# 36           37        299          106                  2  4.0  4.0  8.40
# 39           40        307          108                  2  4.0  3.5  7.70
# 40           41        308          110                  3  3.5  3.0  8.00
# 110         111        305          108                  5  3.0  3.0  8.48
# 112         113        301          107                  3  3.5  3.5  8.34
# 123         124        308          108                  3  3.5  3.5  8.22
# 124         125        301          106                  4  2.5  3.0  8.47
# 158         159        306          106                  2  2.0  2.5  8.14
# 178         179        309          108                  3  2.5  3.0  8.12
# 181         182        305          107                  2  2.5  2.5  8.42
# ...

# %%
#Display records where Chance of Admit &lt; 0.6 or GRE Score &lt; 300.
df[(df["Chance of Admit"]<0.6) | (df["GRE Score"]<300)]
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 8             9        302          102                  1  2.0  1.5  8.00
# 9            10        323          108                  3  3.5  3.0  8.60
# 10           11        325          106                  3  3.5  4.0  8.40
# 15           16        314          105                  3  3.5  2.5  8.30
# 27           28        298           98                  2  1.5  2.5  7.50
# ..          ...        ...          ...                ...  ...  ...   ...
# 377         378        290          100                  1  1.5  2.0  7.56
# 378         379        303           98                  1  2.0  2.5  7.65
# 386         387        302          101                  2  2.5  3.5  7.96
# 387         388        307          105                  2  2.0  3.5  8.10
# 388         389        296           97                  2  1.5  2.0  7.80
#
#      Research  Chance of Admit
# 8           0             0.50
# ...

# %%
#Find the top 10 students with the highest GRE Score.
df.nlargest(10, "GRE Score")
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 25           26        340          120                  5  4.5  4.5  9.60
# 33           34        340          114                  5  4.0  4.0  9.60
# 81           82        340          120                  4  5.0  5.0  9.50
# 84           85        340          115                  5  4.5  4.5  9.45
# 143         144        340          120                  4  4.5  4.0  9.92
# 202         203        340          120                  5  4.5  4.5  9.91
# 284         285        340          112                  4  5.0  4.5  9.66
# 384         385        340          113                  4  5.0  5.0  9.74
# 47           48        339          119                  5  4.5  4.0  9.70
# 130         131        339          114                  5  4.0  4.5  9.76
#
#      Research  Chance of Admit
# 25          1             0.94
# 33          1             0.90
# 81          1             0.96
# ...

# %%
#Display applicants who scored exactly 4.5 in LOR.
df[df["LOR"]==4.5]
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0             1        337          118                  4  4.5  4.5  9.65
# 1             2        324          107                  4  4.0  4.5  8.87
# 11           12        327          111                  4  4.0  4.5  9.00
# 12           13        328          112                  4  4.0  4.5  9.10
# 23           24        334          119                  5  5.0  4.5  9.70
# 25           26        340          120                  5  4.5  4.5  9.60
# 32           33        338          118                  4  3.0  4.5  9.40
# 50           51        313           98                  3  2.5  4.5  8.30
# 82           83        320          110                  5  5.0  4.5  9.22
# 83           84        322          115                  5  4.0  4.5  9.36
# 84           85        340          115                  5  4.5  4.5  9.45
# ...

# %%
#Select students whose SOP rating lies between 3 and 4 (inclusive).
df[df["SOP"].between(3,4)]
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 1             2        324          107                  4  4.0  4.5  8.87
# 2             3        316          104                  3  3.0  3.5  8.00
# 3             4        322          110                  3  3.5  2.5  8.67
# 6             7        321          109                  3  3.0  4.0  8.20
# 7             8        308          101                  2  3.0  4.0  7.90
# ..          ...        ...          ...                ...  ...  ...   ...
# 392         393        326          112                  4  4.0  3.5  9.12
# 393         394        317          104                  2  3.0  3.0  8.76
# 395         396        324          110                  3  3.5  3.5  9.04
# 396         397        325          107                  3  3.0  3.5  9.11
# 398         399        312          103                  3  3.5  4.0  8.78
#
#      Research  Chance of Admit
# 1           1             0.76
# ...

# %%
#Display all students whose University Rating is either 2 or 3.
df[df["University Rating"]==2 | 3]
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 2             3        316          104                  3  3.0  3.5  8.00
# 3             4        322          110                  3  3.5  2.5  8.67
# 6             7        321          109                  3  3.0  4.0  8.20
# 9            10        323          108                  3  3.5  3.0  8.60
# 10           11        325          106                  3  3.5  4.0  8.40
# ..          ...        ...          ...                ...  ...  ...   ...
# 389         390        320          108                  3  3.5  4.0  8.44
# 391         392        318          106                  3  2.0  3.0  8.65
# 395         396        324          110                  3  3.5  3.5  9.04
# 396         397        325          107                  3  3.0  3.5  9.11
# 398         399        312          103                  3  3.5  4.0  8.78
#
#      Research  Chance of Admit
# 2           1             0.72
# ...

# %%
#Filter rows where CGPA is an integer value (e.g., 8.0, 9.0).
df[df["CGPA"] % 1 == 0]
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 2             3        316          104                  3  3.0  3.5   8.0
# 8             9        302          102                  1  2.0  1.5   8.0
# 11           12        327          111                  4  4.0  4.5   9.0
# 13           14        307          109                  3  4.0  3.0   8.0
# 17           18        319          106                  3  4.0  3.0   8.0
# 40           41        308          110                  3  3.5  3.0   8.0
# 52           53        334          116                  4  4.0  3.0   8.0
# 54           55        322          110                  3  3.0  3.5   8.0
# 96           97        306          100                  2  3.0  3.0   8.0
# 251         252        316           99                  2  2.5  3.0   9.0
# 289         290        313          109                  3  4.0  3.5   9.0
# ...

# %%
#Retrieve records where Chance of Admit is between 0.5 and 0.7.
df[df["Chance of Admit"].between(0.5,0.7)]
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 4             5        314          103                  2  2.0  3.0  8.21
# 7             8        308          101                  2  3.0  4.0  7.90
# 8             9        302          102                  1  2.0  1.5  8.00
# 10           11        325          106                  3  3.5  4.0  8.40
# 13           14        307          109                  3  4.0  3.0  8.00
# ..          ...        ...          ...                ...  ...  ...   ...
# 378         379        303           98                  1  2.0  2.5  7.65
# 383         384        300          100                  3  3.0  3.5  8.26
# 387         388        307          105                  2  2.0  3.5  8.10
# 390         391        314          102                  2  2.0  2.5  8.24
# 398         399        312          103                  3  3.5  4.0  8.78
#
#      Research  Chance of Admit
# 4           0             0.65
# ...

# %%
#Select students who scored below average GRE Score.
df[df["GRE Score"] < df["GRE Score"].mean()]
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 2             3        316          104                  3  3.0  3.5  8.00
# 4             5        314          103                  2  2.0  3.0  8.21
# 7             8        308          101                  2  3.0  4.0  7.90
# 8             9        302          102                  1  2.0  1.5  8.00
# 13           14        307          109                  3  4.0  3.0  8.00
# ..          ...        ...          ...                ...  ...  ...   ...
# 386         387        302          101                  2  2.5  3.5  7.96
# 387         388        307          105                  2  2.0  3.5  8.10
# 388         389        296           97                  2  1.5  2.0  7.80
# 390         391        314          102                  2  2.0  2.5  8.24
# 398         399        312          103                  3  3.5  4.0  8.78
#
#      Research  Chance of Admit
# 2           1             0.72
# ...

# %%
#Show all records where TOEFL Score equals the dataset’s maximum TOEFL Score.
df[df["TOEFL Score"]== df["TOEFL Score"]].max()
# Out:
# Serial No.           400.00
# GRE Score            340.00
# TOEFL Score          120.00
# University Rating      5.00
# SOP                    5.00
# LOR                    5.00
# CGPA                   9.92
# Research               1.00
# Chance of Admit        0.97
# dtype: float64

# %%
#Filter students who have both LOR and SOP less than 3.
df[(df["LOR"]<3) &  (df["SOP"]<3)]
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 8             9        302          102                  1  2.0  1.5  8.00
# 27           28        298           98                  2  1.5  2.5  7.50
# 28           29        295           93                  1  2.0  2.0  7.20
# 29           30        310           99                  2  1.5  2.0  7.30
# 37           38        300          105                  1  1.0  2.0  7.80
# ..          ...        ...          ...                ...  ...  ...   ...
# 376         377        297           96                  2  2.5  2.0  7.43
# 377         378        290          100                  1  1.5  2.0  7.56
# 378         379        303           98                  1  2.0  2.5  7.65
# 388         389        296           97                  2  1.5  2.0  7.80
# 390         391        314          102                  2  2.0  2.5  8.24
#
#      Research  Chance of Admit
# 8           0             0.50
# ...

# %%
#Retrieve students who have GRE Score divisible by 5.  Add a newcolumn named GRE_to_TOEFL_Ratio = GRE Score / TOEFL Score.
df[df["GRE Score"] % 5==0]
df['GRE_to_TOEFL_Ratio']=df["GRE Score"] / df["TOEFL Score"]

# %%
#Create a new column Admission_Chance_% = Chance of Admit × 100
df["Admission_Chance_%"]=df["Chance of Admit"]*100

# %%
df
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0             1        337          118                  4  4.5  4.5  9.65
# 1             2        324          107                  4  4.0  4.5  8.87
# 2             3        316          104                  3  3.0  3.5  8.00
# 3             4        322          110                  3  3.5  2.5  8.67
# 4             5        314          103                  2  2.0  3.0  8.21
# ..          ...        ...          ...                ...  ...  ...   ...
# 395         396        324          110                  3  3.5  3.5  9.04
# 396         397        325          107                  3  3.0  3.5  9.11
# 397         398        330          116                  4  5.0  4.5  9.45
# 398         399        312          103                  3  3.5  4.0  8.78
# 399         400        333          117                  4  5.0  4.0  9.66
#
# ...

# %%
df
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0             1        337          118                  4  4.5  4.5  9.65
# 1             2        324          107                  4  4.0  4.5  8.87
# 2             3        316          104                  3  3.0  3.5  8.00
# 3             4        322          110                  3  3.5  2.5  8.67
# 4             5        314          103                  2  2.0  3.0  8.21
# ..          ...        ...          ...                ...  ...  ...   ...
# 395         396        324          110                  3  3.5  3.5  9.04
# 396         397        325          107                  3  3.0  3.5  9.11
# 397         398        330          116                  4  5.0  4.5  9.45
# 398         399        312          103                  3  3.5  4.0  8.78
# 399         400        333          117                  4  5.0  4.0  9.66
#
# ...

# %%
df
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0             1        337          118                  4  4.5  4.5  9.65
# 1             2        324          107                  4  4.0  4.5  8.87
# 2             3        316          104                  3  3.0  3.5  8.00
# 3             4        322          110                  3  3.5  2.5  8.67
# 4             5        314          103                  2  2.0  3.0  8.21
# ..          ...        ...          ...                ...  ...  ...   ...
# 395         396        324          110                  3  3.5  3.5  9.04
# 396         397        325          107                  3  3.0  3.5  9.11
# 397         398        330          116                  4  5.0  4.5  9.45
# 398         399        312          103                  3  3.5  4.0  8.78
# 399         400        333          117                  4  5.0  4.0  9.66
#
# ...

# %%
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0           1        337          118                  4  4.5  4.5  9.65
# 1           2        324          107                  4  4.0  4.5  8.87
# 2           3        316          104                  3  3.0  3.5  8.00
# 3           4        322          110                  3  3.5  2.5  8.67
# 4           5        314          103                  2  2.0  3.0  8.21
#
#    Research  Chance of Admit  GRE_to_TOEFL_Ratio  Admission_Chance_%
# 0         1             0.92            2.855932                92.0
# 1         1             0.76            3.028037                76.0
# 2         1             0.72            3.038462                72.0
# 3         1             0.80            2.927273                80.0
# 4         0             0.65            3.048544                65.0

# %%
#Rename the column Chance of Admit to Admit_Probability.
df.rename(columns={"Chance of Admit": "Admit_Probability"}, inplace=True)

# %%
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0           1        337          118                  4  4.5  4.5  9.65
# 1           2        324          107                  4  4.0  4.5  8.87
# 2           3        316          104                  3  3.0  3.5  8.00
# 3           4        322          110                  3  3.5  2.5  8.67
# 4           5        314          103                  2  2.0  3.0  8.21
#
#    Research  Admit_Probability  GRE_to_TOEFL_Ratio  Admission_Chance_%
# 0         1               0.92            2.855932                92.0
# 1         1               0.76            3.028037                76.0
# 2         1               0.72            3.038462                72.0
# 3         1               0.80            2.927273                80.0
# 4         0               0.65            3.048544                65.0

# %%
#Change all column names to lowercase.
df.columns = df.columns.str.lower()

# %%
df.head()
# Out:
#    serial no.  gre score  toefl score  university rating  sop  lor  cgpa  \
# 0           1        337          118                  4  4.5  4.5  9.65
# 1           2        324          107                  4  4.0  4.5  8.87
# 2           3        316          104                  3  3.0  3.5  8.00
# 3           4        322          110                  3  3.5  2.5  8.67
# 4           5        314          103                  2  2.0  3.0  8.21
#
#    research  admit_probability  gre_to_toefl_ratio  admission_chance_%
# 0         1               0.92            2.855932                92.0
# 1         1               0.76            3.028037                76.0
# 2         1               0.72            3.038462                72.0
# 3         1               0.80            2.927273                80.0
# 4         0               0.65            3.048544                65.0

# %%
df.columns = df.columns.str.upper()
df.head()
# Out:
#    SERIAL NO.  GRE SCORE  TOEFL SCORE  UNIVERSITY RATING  SOP  LOR  CGPA  \
# 0           1        337          118                  4  4.5  4.5  9.65
# 1           2        324          107                  4  4.0  4.5  8.87
# 2           3        316          104                  3  3.0  3.5  8.00
# 3           4        322          110                  3  3.5  2.5  8.67
# 4           5        314          103                  2  2.0  3.0  8.21
#
#    RESEARCH  ADMIT_PROBABILITY  GRE_TO_TOEFL_RATIO  ADMISSION_CHANCE_%
# 0         1               0.92            2.855932                92.0
# 1         1               0.76            3.028037                76.0
# 2         1               0.72            3.038462                72.0
# 3         1               0.80            2.927273                80.0
# 4         0               0.65            3.048544                65.0

# %%
# Drop the column Serial No..
df.drop(columns=["serial no."],inplace=True)

# %%
df.head()
# Out:
#    gre score  toefl score  university rating  sop  lor  cgpa  research  \
# 0        337          118                  4  4.5  4.5  9.65         1
# 1        324          107                  4  4.0  4.5  8.87         1
# 2        316          104                  3  3.0  3.5  8.00         1
# 3        322          110                  3  3.5  2.5  8.67         1
# 4        314          103                  2  2.0  3.0  8.21         0
#
#    admit_probability  gre_to_toefl_ratio  admission_chance_%
# 0               0.92            2.855932                92.0
# 1               0.76            3.028037                76.0
# 2               0.72            3.038462                72.0
# 3               0.80            2.927273                80.0
# 4               0.65            3.048544                65.0

# %%
df.columns
# Out:
# Index(['gre score', 'toefl score', 'university rating', 'sop', 'lor', 'cgpa',
#        'research', 'admit_probability', 'gre_to_toefl_ratio',
#        'admission_chance_%'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['gre score', 'toefl score', 'university rating', 'sop', 'lor', 'cgpa',
#        'research', 'admit_probability', 'gre_to_toefl_ratio',
#        'admission_chance_%'],
#       dtype='object')

# %%
#Round all values in CGPA to one decimal place.
df['cgpa'].round(1)
# Out:
# 0      9.6
# 1      8.9
# 2      8.0
# 3      8.7
# 4      8.2
#       ...
# 395    9.0
# 396    9.1
# 397    9.4
# 398    8.8
# 399    9.7
# Name: cgpa, Length: 400, dtype: float64

# %%
df.head()
# Out:
#    gre score  toefl score  university rating  sop  lor  cgpa  research  \
# 0        337          118                  4  4.5  4.5  9.65         1
# 1        324          107                  4  4.0  4.5  8.87         1
# 2        316          104                  3  3.0  3.5  8.00         1
# 3        322          110                  3  3.5  2.5  8.67         1
# 4        314          103                  2  2.0  3.0  8.21         0
#
#    admit_probability  gre_to_toefl_ratio  admission_chance_%
# 0               0.92            2.855932                92.0
# 1               0.76            3.028037                76.0
# 2               0.72            3.038462                72.0
# 3               0.80            2.927273                80.0
# 4               0.65            3.048544                65.0

# %%
#Replace all University Rating values of 5 with 10.
df["university rating"].replace(5,10)
# Out:
# 0      4
# 1      4
# 2      3
# 3      3
# 4      2
#       ..
# 395    3
# 396    3
# 397    4
# 398    3
# 399    4
# Name: university rating, Length: 400, dtype: int64

# %%
df['university rating']= df["university rating"].replace(5,10)

# %%
df
# Out:
#      gre score  toefl score  university rating  sop  lor  cgpa  research  \
# 0          337          118                  4  4.5  4.5  9.65         1
# 1          324          107                  4  4.0  4.5  8.87         1
# 2          316          104                  3  3.0  3.5  8.00         1
# 3          322          110                  3  3.5  2.5  8.67         1
# 4          314          103                  2  2.0  3.0  8.21         0
# ..         ...          ...                ...  ...  ...   ...       ...
# 395        324          110                  3  3.5  3.5  9.04         1
# 396        325          107                  3  3.0  3.5  9.11         1
# 397        330          116                  4  5.0  4.5  9.45         1
# 398        312          103                  3  3.5  4.0  8.78         0
# 399        333          117                  4  5.0  4.0  9.66         1
#
#      admit_probability  gre_to_toefl_ratio  admission_chance_%
# ...

# %%
#Convert Research column values from 0/1 to “No”/“Yes”.
df['research'].replace({0:"No",1:"Yes"},inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_15336\4203515883.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['research'].replace({0:"No",1:"Yes"},inplace=True)

# %%
df
# Out:
#      gre score  toefl score  university rating  sop  lor  cgpa research  \
# 0          337          118                  4  4.5  4.5  9.65      Yes
# 1          324          107                  4  4.0  4.5  8.87      Yes
# 2          316          104                  3  3.0  3.5  8.00      Yes
# 3          322          110                  3  3.5  2.5  8.67      Yes
# 4          314          103                  2  2.0  3.0  8.21       No
# ..         ...          ...                ...  ...  ...   ...      ...
# 395        324          110                  3  3.5  3.5  9.04      Yes
# 396        325          107                  3  3.0  3.5  9.11      Yes
# 397        330          116                  4  5.0  4.5  9.45      Yes
# 398        312          103                  3  3.5  4.0  8.78       No
# 399        333          117                  4  5.0  4.0  9.66      Yes
#
#      admit_probability  gre_to_toefl_ratio  admission_chance_%
# ...

# %%
#Create a new column GRE_Level = “High” if GRE ≥ 320 else “Low”.
df["gre_level"] = df["gre score"].apply(lambda x: "High" if x >= 320 else "Low")

# %%
df
# Out:
#      gre score  toefl score  university rating  sop  lor  cgpa research  \
# 0          337          118                  4  4.5  4.5  9.65      Yes
# 1          324          107                  4  4.0  4.5  8.87      Yes
# 2          316          104                  3  3.0  3.5  8.00      Yes
# 3          322          110                  3  3.5  2.5  8.67      Yes
# 4          314          103                  2  2.0  3.0  8.21       No
# ..         ...          ...                ...  ...  ...   ...      ...
# 395        324          110                  3  3.5  3.5  9.04      Yes
# 396        325          107                  3  3.0  3.5  9.11      Yes
# 397        330          116                  4  5.0  4.5  9.45      Yes
# 398        312          103                  3  3.5  4.0  8.78       No
# 399        333          117                  4  5.0  4.0  9.66      Yes
#
#      admit_probability  gre_to_toefl_ratio  admission_chance_% gre_level
# ...

# %%
#Normalize CGPA column to range 0–1 using min-max scaling (without sklearn)

# %%
#Increase all TOEFL Score values by 2 points.
df['toefl score'] = df['toefl score'].round(2)

# %%
df.head()
# Out:
#    gre score  toefl score  university rating  sop  lor  cgpa research  \
# 0        337          118                  4  4.5  4.5  9.65      Yes
# 1        324          107                  4  4.0  4.5  8.87      Yes
# 2        316          104                  3  3.0  3.5  8.00      Yes
# 3        322          110                  3  3.5  2.5  8.67      Yes
# 4        314          103                  2  2.0  3.0  8.21       No
#
#    admit_probability  gre_to_toefl_ratio  admission_chance_% gre_level
# 0               0.92            2.855932                92.0      High
# 1               0.76            3.028037                76.0      High
# 2               0.72            3.038462                72.0       Low
# 3               0.80            2.927273                80.0      High
# 4               0.65            3.048544                65.0       Low

# %%
#Add a column Weighted_Score = GRE Score * 0.3 + TOEFL Score * 0.2 +CGPA * 0.5.
df["Weighted_Score"]=(df['gre score']*0.3)+(df['toefl score']*0.2)+(df['cgpa']*0.5)

# %%
df
# Out:
#      gre score  toefl score  university rating  sop  lor  cgpa research  \
# 0          337          118                  4  4.5  4.5  9.65      Yes
# 1          324          107                  4  4.0  4.5  8.87      Yes
# 2          316          104                  3  3.0  3.5  8.00      Yes
# 3          322          110                  3  3.5  2.5  8.67      Yes
# 4          314          103                  2  2.0  3.0  8.21       No
# ..         ...          ...                ...  ...  ...   ...      ...
# 395        324          110                  3  3.5  3.5  9.04      Yes
# 396        325          107                  3  3.0  3.5  9.11      Yes
# 397        330          116                  4  5.0  4.5  9.45      Yes
# 398        312          103                  3  3.5  4.0  8.78       No
# 399        333          117                  4  5.0  4.0  9.66      Yes
#
#      admit_probability  gre_to_toefl_ratio  admission_chance_% gre_level  \
# ...

# %%
#Drop all duplicate rows if any.

# %%
#Replace all SOP values less than 2 with the mean SOP.
df["SOP"]=

# %%
#Create a new column combining University Rating and Research (e.g 'Rating-Research').
